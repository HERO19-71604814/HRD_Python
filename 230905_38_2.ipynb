# %%
file = open('data/basic.txt', 'a')
file.write('\nHello Python!')
file.close()

# %%
with open('data/basic.txt', 'a') as f:
    f.write('\n어서와!!!!')

# %%
file = open('data/basic.txt', 'r')
data = file.read()
print(data)
# Out:
# 안녕 파이썬!Hello Python!
# Hello Python!

# %%
import random

first_name = ['김','이','박','최', '정','전','강','심','오','소','고','선우','조',
             '신','임','편','위','제갈','장', '감','유','우','한','표','성','나','주',
             '배','송','홍','곽','독고','구','백','허']
last_name = ['호','정','순','결','빈','다','수','웅','민','재','훈','영','기','철','란',
            '성','경','표','석','우','용','배','서','진','종','균','태','인','자','윤',
            '옥','명','준','아','하','은','권','비','동','희','송','도','보','검','현',
            '흥','혜', '교','지', '남']

person = []

for i in range(1000):
    name = first_name[random.randint(0,len(first_name)-1)]
    name += last_name[random.randint(0,len(last_name)-1)]
    name += last_name[random.randint(0,len(last_name)-1)]
    height = random.randint(150, 200)
    weight = random.randint(40, 130)
    person.append([name, height, weight])

with open('data/info.txt', 'w') as file:
    for per in person:
        print(per)
        file.write("{}, {}, {}".format(per[0], per[1], per[2]) + '\n')
# Out:
# ['오자호', 153, 74]
# ['감순결', 185, 58]
# ['나민웅', 183, 123]
# ['최남하', 190, 114]
# ['독고명인', 193, 104]
# ['성경경', 199, 119]
# ['임우훈', 178, 97]
# ['우결인', 177, 81]
# ['박검정', 157, 84]
# ['성기흥', 172, 47]
# ['홍서보', 154, 77]
# ['배진철', 171, 45]
# ['심웅명', 150, 113]
# ['박종표', 183, 126]
# ['김현희', 160, 41]
# ['편교성', 199, 123]
# ['오자은', 171, 129]
# ['소철윤', 152, 122]
# ['신다란', 190, 94]
# ['정지진', 191, 77]
# ['신재남', 191, 117]
# ['한현하', 156, 100]
# ['장결동', 162, 73]
# ['전경남', 163, 122]
# ['장윤수', 158, 71]
# ['백배도', 192, 101]
# ['허다권', 166, 98]
# ['이하순', 176, 47]
# ['허균하', 169, 71]
# ['우수석', 166, 75]
# ['나용동', 150, 112]
# ['우진민', 155, 129]
# ['한석기', 188, 98]
# ['소서검', 171, 47]
# ['소옥수', 152, 48]
# ['구재정', 178, 49]
# ['구균지', 157, 55]
# ['허경표', 196, 82]
# ['나명수', 197, 76]
# ['편준남', 191, 88]
# ['제갈남훈', 177, 116]
# ['고정은', 186, 59]
# ['전검아', 198, 127]
# ['심자도', 177, 120]
# ['최성윤', 166, 98]
# ['편희웅', 167, 122]
# ['위진동', 157, 70]
# ['허수옥', 180, 73]
# ['배배도', 186, 47]
# ['독고현동', 167, 67]
# ['독고민준', 168, 72]
# ['배은송', 188, 42]
# ['장명기', 189, 104]
# ['고비결', 167, 60]
# ['고란결', 167, 75]
# ['선우철도', 155, 51]
# ['백명자', 165, 119]
# ['최송은', 178, 42]
# ['홍란종', 155, 110]
# ['성철수', 199, 70]
# ['오비지', 167, 127]
# ['표진하', 164, 95]
# ['김수기', 199, 97]
# ['강호호', 176, 46]
# ['편준태', 182, 109]
# ['소경흥', 190, 79]
# ['표은희', 184, 104]
# ['허옥진', 184, 60]
# ['허성검', 167, 89]
# ['백호윤', 157, 66]
# ['장권진', 200, 49]
# ['감보비', 165, 66]
# ['심수명', 195, 65]
# ['홍현혜', 167, 102]
# ['송하교', 155, 42]
# ['유혜교', 150, 103]
# ['정준동', 183, 83]
# ['한은교', 165, 57]
# ['홍송순', 167, 64]
# ['송훈지', 188, 51]
# ['선우훈남', 196, 106]
# ['송비교', 171, 122]
# ['구서웅', 190, 87]
# ['성태태', 186, 99]
# ['독고송다', 151, 76]
# ['강배아', 162, 107]
# ['박자성', 165, 49]
# ['김수기', 163, 63]
# ['위보현', 198, 80]
# ['심도송', 173, 100]
# ['고도석', 158, 117]
# ['편태훈', 199, 124]
# ['김균현', 190, 40]
# ['선우성성', 170, 128]
# ['박교인', 188, 91]
# ['한윤권', 162, 59]
# ['장동권', 157, 102]
# ['허혜동', 169, 96]
# ['독고기남', 178, 40]
# ['독고웅준', 190, 83]
# ['위윤표', 200, 87]
# ['성기용', 167, 69]
# ['심수정', 180, 84]
# ['제갈명인', 176, 49]
# ['심흥훈', 168, 66]
# ['강균성', 160, 45]
# ['장윤권', 174, 121]
# ['송권민', 175, 117]
# ['심성비', 187, 127]
# ['제갈훈보', 171, 72]
# ['제갈인교', 199, 55]
# ['김윤다', 196, 70]
# ['백기도', 162, 125]
# ['최경철', 180, 76]
# ['표정준', 196, 96]
# ['우석송', 181, 83]
# ['우수교', 188, 62]
# ['오준동', 191, 128]
# ['강기표', 178, 119]
# ['최훈종', 169, 75]
# ['전남진', 160, 50]
# ['최웅교', 195, 40]
# ['허보철', 186, 70]
# ['홍현철', 158, 41]
# ['백송성', 165, 40]
# ['우수동', 166, 54]
# ['홍빈검', 197, 49]
# ['오권다', 172, 103]
# ['오태진', 197, 77]
# ['유영지', 180, 122]
# ['정옥지', 178, 127]
# ['백윤자', 193, 56]
# ['독고영용', 198, 111]
# ['홍태아', 153, 46]
# ['성송용', 150, 101]
# ['우도검', 155, 60]
# ['제갈동흥', 173, 83]
# ['곽성결', 187, 125]
# ['독고남도', 199, 62]
# ['감지순', 154, 54]
# ['나수아', 155, 127]
# ['허석태', 170, 80]
# ['박기보', 153, 78]
# ['소하보', 175, 114]
# ['신경지', 168, 50]
# ['소석서', 200, 103]
# ['최검빈', 156, 41]
# ['선우흥철', 185, 78]
# ['표옥지', 163, 65]
# ['나기옥', 171, 41]
# ['홍순빈', 162, 98]
# ['박균진', 186, 82]
# ['선우민우', 156, 65]
# ['최용보', 161, 49]
# ['홍우남', 182, 51]
# ['최훈빈', 181, 73]
# ['감호성', 164, 117]
# ['신지석', 151, 42]
# ['백수빈', 189, 128]
# ['고철명', 189, 79]
# ['김교송', 172, 75]
# ['곽진성', 165, 129]
# ['성하윤', 185, 115]
# ['조순송', 198, 99]
# ['송석란', 192, 40]
# ['배빈우', 190, 90]
# ['신훈균', 180, 128]
# ['주현란', 158, 64]
# ['소용은', 161, 75]
# ['홍도흥', 153, 79]
# ['송석은', 150, 130]
# ['구지진', 187, 47]
# ['임비윤', 155, 112]
# ['유웅민', 171, 70]
# ['홍보서', 178, 116]
# ['이철표', 167, 126]
# ['강명동', 196, 80]
# ['홍훈하', 159, 103]
# ['우송명', 183, 104]
# ['이교우', 150, 121]
# ['선우서웅', 185, 89]
# ['정현인', 177, 74]
# ['위균정', 162, 120]
# ['고호하', 197, 114]
# ['표순권', 166, 43]
# ['독고남도', 196, 86]
# ['유준권', 169, 72]
# ['허란빈', 161, 102]
# ['배준석', 161, 120]
# ['강보성', 181, 63]
# ['소송하', 189, 61]
# ['감아명', 195, 94]
# ['표도순', 167, 110]
# ['위지민', 172, 92]
# ['유정동', 187, 84]
# ['정수자', 175, 65]
# ['신다흥', 186, 110]
# ['오흥희', 183, 47]
# ['성현석', 179, 93]
# ['심송우', 172, 74]
# ['나표윤', 154, 40]
# ['우수윤', 188, 47]
# ['제갈영용', 184, 94]
# ['홍혜종', 154, 46]
# ['오빈철', 199, 59]
# ['김동순', 187, 48]
# ['신석아', 176, 40]
# ['제갈진배', 151, 60]
# ['우명명', 163, 56]
# ['표란송', 178, 55]
# ['성준도', 178, 57]
# ['나송서', 168, 108]
# ['홍재용', 176, 89]
# ['제갈란란', 163, 51]
# ['한동아', 169, 109]
# ['나표석', 164, 96]
# ['강정순', 180, 68]
# ['정지자', 181, 108]
# ['심흥희', 159, 57]
# ['제갈준빈', 185, 126]
# ['감송하', 162, 87]
# ['강비용', 193, 92]
# ['송훈진', 197, 103]
# ['감영비', 168, 121]
# ['성하보', 188, 125]
# ['최철석', 158, 121]
# ['독고하철', 171, 103]
# ['백현은', 167, 116]
# ['이비수', 156, 44]
# ['정명영', 194, 124]
# ['감도송', 188, 46]
# ['허다정', 181, 112]
# ['최호자', 162, 97]
# ['구영흥', 197, 120]
# ['정수표', 179, 110]
# ['성경란', 183, 67]
# ['조호웅', 172, 52]
# ['고결경', 180, 49]
# ['허배민', 178, 114]
# ['독고재석', 174, 109]
# ['허비재', 183, 81]
# ['위남철', 194, 118]
# ['표결결', 162, 58]
# ['송아서', 193, 91]
# ['배호윤', 155, 44]
# ['독고남서', 181, 129]
# ['표송표', 171, 72]
# ['배지옥', 194, 61]
# ['배용옥', 184, 128]
# ['한수철', 156, 65]
# ['허정균', 160, 98]
# ['장훈수', 177, 126]
# ['송서옥', 169, 118]
# ['독고란아', 175, 125]
# ['한진호', 187, 113]
# ['나기희', 196, 91]
# ['유재순', 200, 48]
# ['배하송', 179, 45]
# ['심성교', 170, 71]
# ['홍현옥', 164, 101]
# ['전균서', 197, 43]
# ['정용진', 176, 89]
# ['신권란', 179, 66]
# ['허윤호', 178, 130]
# ['최종아', 153, 126]
# ['장수인', 190, 94]
# ['허송다', 161, 98]
# ['유교서', 151, 123]
# ['강하균', 192, 53]
# ['송송진', 179, 114]
# ['조준비', 175, 124]
# ['장명도', 200, 128]
# ['신우성', 157, 63]
# ['구순태', 173, 42]
# ['임기기', 169, 123]
# ['편남비', 176, 42]
# ['감검배', 173, 41]
# ['감성명', 199, 100]
# ['주수영', 196, 88]
# ['한진아', 165, 114]
# ['구준옥', 200, 104]
# ['주용도', 164, 63]
# ['임웅태', 177, 62]
# ['홍준민', 177, 55]
# ['홍영태', 167, 106]
# ['고석흥', 153, 64]
# ['신훈동', 176, 78]
# ['박아도', 179, 75]
# ['배비검', 155, 82]
# ['주수권', 196, 94]
# ['편명흥', 183, 89]
# ['우흥다', 172, 107]
# ['소도기', 156, 116]
# ['우정서', 188, 95]
# ['감송은', 194, 70]
# ['유정웅', 172, 62]
# ['선우하지', 188, 88]
# ['오비준', 159, 46]
# ['주보경', 198, 59]
# ['허다용', 172, 123]
# ['우은보', 175, 78]
# ['유지송', 159, 101]
# ['소희권', 152, 42]
# ['유인성', 184, 70]
# ['정흥태', 187, 94]
# ['독고성흥', 184, 85]
# ['박웅민', 155, 118]
# ['송남비', 192, 125]
# ['오경희', 166, 41]
# ['주서결', 181, 77]
# ['나현기', 159, 100]
# ['오빈준', 199, 118]
# ['구인아', 168, 94]
# ['심준용', 157, 105]
# ['전배표', 159, 116]
# ['조수순', 182, 66]
# ['소희민', 192, 50]
# ['독고란비', 199, 112]
# ['소하윤', 185, 57]
# ['우석기', 156, 68]
# ['임배현', 155, 59]
# ['이권희', 182, 113]
# ['홍용은', 189, 98]
# ['최동권', 165, 55]
# ['성결성', 175, 47]
# ['성남기', 184, 42]
# ['고아결', 179, 81]
# ['신아교', 170, 129]
# ['박권웅', 178, 54]
# ['선우아민', 190, 124]
# ['전서민', 189, 130]
# ['제갈동우', 154, 122]
# ['허영다', 181, 42]
# ['나수하', 195, 84]
# ['제갈성은', 191, 98]
# ['위송훈', 165, 95]
# ['신명다', 175, 85]
# ['전옥다', 157, 93]
# ['허종철', 192, 69]
# ['한동용', 182, 56]
# ['우흥결', 163, 124]
# ['성성정', 199, 48]
# ['박검혜', 156, 118]
# ['구진진', 153, 95]
# ['최교호', 169, 114]
# ['전영석', 188, 90]
# ['표은결', 157, 73]
# ['장권성', 188, 77]
# ['소순옥', 200, 112]
# ['고비웅', 170, 97]
# ['홍동서', 173, 128]
# ['성우태', 154, 120]
# ['장배서', 180, 58]
# ['홍기흥', 179, 71]
# ['감균지', 199, 71]
# ['조훈준', 160, 113]
# ['백보은', 199, 73]
# ['표태빈', 173, 90]
# ['위하자', 192, 43]
# ['이준검', 161, 108]
# ['이경순', 163, 41]
# ['강호명', 187, 114]
# ['선우혜민', 170, 118]
# ['장서흥', 188, 95]
# ['우수지', 174, 79]
# ['홍지웅', 163, 129]
# ['강옥자', 179, 53]
# ['유영철', 164, 130]
# ['감용석', 181, 107]
# ['장정우', 163, 115]
# ['한동용', 182, 60]
# ['고훈훈', 182, 82]
# ['백민종', 190, 53]
# ['김결영', 184, 45]
# ['백용보', 199, 62]
# ['위균종', 159, 113]
# ['송표철', 200, 43]
# ['위수아', 157, 114]
# ['전훈남', 161, 64]
# ['곽비경', 185, 70]
# ['전교자', 153, 129]
# ['곽지재', 169, 45]
# ['임다표', 168, 48]
# ['고하철', 168, 72]
# ['전영진', 155, 129]
# ['오성영', 154, 106]
# ['배혜영', 171, 64]
# ['고아진', 175, 123]
# ['김기호', 155, 103]
# ['이검다', 160, 58]
# ['주현다', 155, 68]
# ['주서혜', 179, 41]
# ['송수철', 173, 103]
# ['이도권', 159, 75]
# ['배자현', 158, 62]
# ['나태비', 151, 49]
# ['제갈수지', 151, 85]
# ['정종란', 180, 102]
# ['박지종', 193, 73]
# ['심빈용', 171, 42]
# ['김진자', 187, 62]
# ['장영윤', 158, 82]
# ['김권진', 190, 116]
# ['이서란', 151, 62]
# ['신혜민', 182, 69]
# ['강란지', 176, 95]
# ['홍도인', 180, 107]
# ['임지태', 191, 81]
# ['장수인', 190, 74]
# ['장수우', 184, 66]
# ['고성기', 171, 105]
# ['소지성', 162, 52]
# ['소재교', 179, 72]
# ['임보권', 170, 68]
# ['성호배', 169, 96]
# ['곽배은', 192, 47]
# ['고철란', 188, 114]
# ['박비민', 150, 110]
# ['오다도', 181, 67]
# ['곽남태', 200, 85]
# ['강우은', 151, 78]
# ['한호교', 200, 59]
# ['박검준', 168, 85]
# ['김재검', 164, 63]
# ['고아배', 191, 126]
# ['백수웅', 199, 104]
# ['임권결', 165, 80]
# ['배검진', 193, 130]
# ['신철비', 190, 73]
# ['구성다', 178, 103]
# ['강검남', 198, 75]
# ['오철용', 181, 61]
# ['강종우', 189, 82]
# ['선우종비', 185, 65]
# ['강태준', 196, 85]
# ['유도배', 181, 51]
# ['신하비', 150, 63]
# ['강흥민', 165, 55]
# ['신영은', 191, 73]
# ['나배순', 193, 42]
# ['배현기', 183, 117]
# ['오우호', 151, 68]
# ['나태호', 167, 46]
# ['유인란', 155, 123]
# ['장성보', 171, 59]
# ['구태균', 162, 92]
# ['제갈혜윤', 162, 76]
# ['조호하', 167, 44]
# ['강옥배', 183, 41]
# ['주하다', 183, 71]
# ['조균보', 165, 55]
# ['표희자', 157, 99]
# ['나윤진', 181, 107]
# ['박순용', 155, 130]
# ['표준웅', 179, 54]
# ['백우정', 174, 55]
# ['구남균', 161, 113]
# ['김송철', 176, 79]
# ['표서혜', 190, 95]
# ['위표도', 173, 53]
# ['이하배', 151, 90]
# ['성표정', 155, 49]
# ['강재아', 170, 128]
# ['감현표', 181, 96]
# ['임아웅', 159, 70]
# ['장영혜', 168, 40]
# ['배남명', 157, 117]
# ['나결교', 183, 40]
# ['성훈권', 185, 55]
# ['김빈태', 175, 84]
# ['나비희', 155, 72]
# ['박호동', 150, 77]
# ['심자송', 198, 93]
# ['성순동', 150, 41]
# ['소권진', 181, 51]
# ['이기수', 178, 72]
# ['전지인', 183, 115]
# ['표은비', 185, 49]
# ['정흥송', 164, 44]
# ['박영하', 158, 48]
# ['장재경', 179, 73]
# ['제갈민교', 169, 75]
# ['심호기', 174, 57]
# ['우재표', 178, 83]
# ['성옥웅', 159, 97]
# ['임결명', 169, 119]
# ['독고하혜', 194, 128]
# ['한혜영', 199, 62]
# ['김용동', 150, 115]
# ['박송민', 200, 114]
# ['한자인', 185, 69]
# ['감호윤', 167, 78]
# ['성종기', 163, 45]
# ['곽은희', 187, 91]
# ['임배아', 156, 42]
# ['조순비', 171, 122]
# ['독고지흥', 184, 45]
# ['표용정', 196, 43]
# ['나결우', 185, 50]
# ['독고도교', 195, 112]
# ['편남석', 175, 101]
# ['심비다', 184, 84]
# ['구용경', 189, 49]
# ['백진비', 175, 126]
# ['독고균석', 152, 79]
# ['강수순', 152, 62]
# ['고교아', 197, 94]
# ['우정성', 185, 84]
# ['전경진', 200, 64]
# ['허자균', 190, 89]
# ['정아우', 163, 72]
# ['최훈비', 189, 80]
# ['강수호', 171, 80]
# ['유검옥', 160, 108]
# ['임정호', 168, 49]
# ['한영호', 165, 45]
# ['송하균', 198, 126]
# ['장순준', 176, 83]
# ['표혜우', 163, 103]
# ['구영수', 183, 80]
# ['한인교', 153, 43]
# ['구빈보', 170, 98]
# ['신우다', 159, 87]
# ['심은철', 198, 62]
# ['편아옥', 193, 59]
# ['우균영', 173, 50]
# ['이경진', 188, 115]
# ['오빈아', 193, 120]
# ['주결영', 195, 72]
# ['소우권', 178, 109]
# ['강검옥', 150, 59]
# ['편송표', 191, 70]
# ['소정영', 176, 45]
# ['소지경', 178, 103]
# ['김동수', 155, 76]
# ['주자호', 178, 87]
# ['감용교', 183, 128]
# ['표송권', 162, 106]
# ['박배현', 199, 52]
# ['감란검', 193, 115]
# ['최희준', 174, 45]
# ['장보권', 182, 106]
# ['임순지', 184, 55]
# ['주정진', 200, 72]
# ['우성혜', 168, 113]
# ['유정기', 195, 43]
# ['표재윤', 196, 60]
# ['우영서', 168, 95]
# ['송종비', 159, 52]
# ['우빈기', 185, 84]
# ['오검자', 150, 86]
# ['감동수', 169, 122]
# ['홍란희', 158, 88]
# ['배빈영', 191, 64]
# ['백도명', 194, 99]
# ['장권훈', 166, 54]
# ['제갈서성', 154, 82]
# ['김수균', 171, 80]
# ['감우호', 151, 57]
# ['신기흥', 184, 104]
# ['장종윤', 173, 60]
# ['나경석', 175, 59]
# ['선우균혜', 179, 62]
# ['나민수', 189, 108]
# ['한도성', 152, 50]
# ['백보도', 199, 67]
# ['소태영', 156, 57]
# ['오준기', 199, 90]
# ['신자석', 187, 94]
# ['최윤다', 198, 90]
# ['최자현', 179, 119]
# ['송재재', 200, 44]
# ['조경정', 164, 53]
# ['곽진훈', 194, 40]
# ['한명은', 199, 114]
# ['최영지', 150, 115]
# ['선우희서', 173, 129]
# ['장동정', 159, 120]
# ['곽기지', 197, 76]
# ['심검배', 184, 47]
# ['홍지철', 162, 94]
# ['주민민', 168, 115]
# ['홍검석', 182, 99]
# ['최준표', 182, 129]
# ['송서경', 200, 101]
# ['김경송', 154, 104]
# ['장하기', 161, 98]
# ['김다검', 180, 63]
# ['나혜아', 158, 52]
# ['나태재', 155, 97]
# ['조하기', 152, 118]
# ['오순남', 159, 79]
# ['임권빈', 171, 123]
# ['우태민', 166, 80]
# ['우우흥', 155, 73]
# ['홍결다', 192, 123]
# ['곽하경', 169, 68]
# ['우진도', 163, 100]
# ['선우호보', 184, 77]
# ['신진인', 153, 40]
# ['우진권', 180, 104]
# ['김옥하', 193, 80]
# ['선우순송', 200, 61]
# ['정경용', 161, 74]
# ['위정남', 194, 99]
# ['주혜용', 156, 130]
# ['독고우기', 157, 97]
# ['구남우', 185, 81]
# ['심진혜', 152, 101]
# ['임훈은', 193, 109]
# ['최석영', 190, 92]
# ['소지비', 162, 102]
# ['박종권', 173, 53]
# ['선우영결', 182, 91]
# ['송경현', 192, 110]
# ['임현순', 187, 83]
# ['김하지', 188, 91]
# ['김웅영', 164, 110]
# ['김민혜', 193, 55]
# ['심균자', 179, 59]
# ['독고흥검', 194, 43]
# ['표인준', 189, 108]
# ['구남빈', 171, 119]
# ['고현태', 185, 92]
# ['고권준', 172, 69]
# ['신옥민', 172, 87]
# ['편준동', 162, 42]
# ['배훈은', 186, 117]
# ['소아은', 177, 99]
# ['강서영', 168, 46]
# ['제갈균철', 192, 121]
# ['홍비은', 196, 44]
# ['송표남', 156, 79]
# ['이진배', 154, 94]
# ['감자서', 199, 116]
# ['위순현', 173, 60]
# ['허서기', 161, 119]
# ['제갈혜철', 178, 129]
# ['오수철', 191, 54]
# ['선우재준', 164, 72]
# ['편준철', 175, 123]
# ['위혜도', 168, 40]
# ['전민보', 171, 50]
# ['한하명', 152, 40]
# ['한동우', 193, 49]
# ['성명석', 155, 110]
# ['표검동', 179, 84]
# ['강보희', 163, 63]
# ['독고란수', 162, 125]
# ['이균우', 184, 126]
# ['임은보', 152, 126]
# ['선우석란', 177, 63]
# ['독고균성', 172, 64]
# ['홍명은', 184, 92]
# ['홍경교', 186, 56]
# ['임호지', 168, 97]
# ['주옥민', 178, 72]
# ['백하지', 174, 84]
# ['편혜석', 158, 120]
# ['백혜기', 150, 90]
# ['김하혜', 183, 56]
# ['한자용', 189, 65]
# ['배우석', 190, 52]
# ['오순교', 179, 77]
# ['조경아', 182, 110]
# ['장경종', 174, 57]
# ['우흥다', 190, 52]
# ['김종송', 150, 56]
# ['오자종', 178, 73]
# ['박은다', 153, 102]
# ['장송자', 190, 103]
# ['오도하', 171, 46]
# ['나교보', 200, 117]
# ['백아준', 191, 73]
# ['조남은', 180, 54]
# ['박태태', 195, 42]
# ['임용은', 180, 104]
# ['홍영수', 162, 122]
# ['소우명', 169, 91]
# ['신인권', 179, 75]
# ['구검인', 155, 87]
# ['박표진', 171, 45]
# ['유보균', 154, 112]
# ['편용민', 176, 102]
# ['유태철', 163, 127]
# ['제갈현빈', 156, 68]
# ['소민아', 159, 47]
# ['오재교', 199, 68]
# ['위순경', 166, 51]
# ['편석석', 182, 94]
# ['정남혜', 194, 96]
# ['허다하', 183, 95]
# ['배철기', 168, 48]
# ['나현윤', 178, 82]
# ['위우민', 177, 128]
# ['한수순', 190, 75]
# ['장훈영', 199, 115]
# ['김남남', 192, 80]
# ['조훈영', 170, 110]
# ['유균진', 168, 43]
# ['유윤하', 152, 82]
# ['백표배', 176, 73]
# ['나서철', 155, 72]
# ['편자혜', 166, 43]
# ['주성비', 155, 119]
# ['감보용', 196, 86]
# ['허배지', 181, 55]
# ['유기권', 156, 54]
# ['선우서은', 186, 66]
# ['허민동', 176, 51]
# ['성순표', 152, 128]
# ['선우석은', 160, 87]
# ['고훈표', 177, 82]
# ['선우순영', 185, 71]
# ['우호다', 200, 75]
# ['독고영균', 171, 51]
# ['선우아진', 192, 69]
# ['강자종', 162, 43]
# ['감희지', 199, 109]
# ['조기성', 163, 113]
# ['조도배', 164, 74]
# ['주웅흥', 176, 46]
# ['표은송', 187, 75]
# ['허성명', 182, 107]
# ['이철정', 187, 72]
# ['조권빈', 177, 117]
# ['성우경', 179, 63]
# ['조철웅', 190, 42]
# ['제갈비인', 199, 50]
# ['주윤민', 165, 129]
# ['조빈결', 195, 101]
# ['조희아', 169, 126]
# ['정민남', 174, 67]
# ['홍준비', 157, 88]
# ['선우영검', 168, 51]
# ['한종남', 160, 50]
# ['우지민', 169, 51]
# ['임훈교', 163, 90]
# ['감은서', 176, 68]
# ['성성배', 165, 40]
# ['구명종', 189, 46]
# ['한정현', 190, 84]
# ['임종교', 153, 66]
# ['선우송송', 194, 81]
# ['오준다', 161, 112]
# ['허비호', 158, 108]
# ['이은철', 155, 72]
# ['신재란', 157, 64]
# ['우윤호', 155, 117]
# ['백도윤', 166, 77]
# ['위석준', 198, 74]
# ['박영영', 188, 121]
# ['오결란', 183, 96]
# ['최호서', 181, 70]
# ['한표준', 180, 104]
# ['성검도', 159, 92]
# ['유아하', 186, 86]
# ['송인우', 166, 85]
# ['독고검남', 171, 56]
# ['소다성', 157, 113]
# ['배남경', 198, 110]
# ['제갈경배', 162, 93]
# ['장옥검', 169, 96]
# ['유진하', 184, 100]
# ['임검아', 160, 47]
# ['최보윤', 150, 119]
# ['구흥도', 163, 129]
# ['제갈경배', 152, 66]
# ['제갈비다', 166, 113]
# ['신교다', 183, 80]
# ['홍권희', 169, 125]
# ['김기민', 184, 62]
# ['김남수', 189, 63]
# ['송석명', 175, 130]
# ['백표혜', 189, 106]
# ['유옥지', 191, 70]
# ['박아옥', 171, 50]
# ['최기종', 159, 68]
# ['나지비', 177, 73]
# ['전민권', 174, 84]
# ['조준준', 189, 53]
# ['장현자', 167, 118]
# ['선우태용', 192, 98]
# ['신동철', 191, 90]
# ['허성란', 168, 98]
# ['한정결', 162, 55]
# ['나교정', 151, 64]
# ['주지수', 193, 94]
# ['심명권', 182, 114]
# ['편지도', 199, 99]
# ['위다순', 186, 76]
# ['홍지진', 199, 83]
# ['독고용옥', 157, 59]
# ['신지도', 156, 129]
# ['장성수', 199, 114]
# ['성진교', 160, 126]
# ['성보영', 171, 47]
# ['곽권옥', 198, 79]
# ['박석인', 196, 124]
# ['편종윤', 150, 105]
# ['배석하', 172, 118]
# ['곽석순', 153, 64]
# ['배석태', 178, 81]
# ['송서웅', 154, 60]
# ['편진옥', 175, 97]
# ['백동란', 197, 45]
# ['오도배', 170, 87]
# ['고준서', 163, 106]
# ['독고동결', 158, 48]
# ['조인종', 156, 129]
# ['감영혜', 166, 97]
# ['제갈보재', 186, 56]
# ['감희수', 158, 44]
# ['장표남', 156, 97]
# ['우용태', 190, 74]
# ['김영진', 175, 86]
# ['임우권', 162, 124]
# ['위아철', 150, 55]
# ['한희도', 160, 48]
# ['신란아', 189, 71]
# ['홍현송', 181, 40]
# ['백희재', 184, 66]
# ['나아지', 150, 45]
# ['독고순검', 155, 60]
# ['성윤재', 189, 56]
# ['표수자', 166, 66]
# ['최자현', 190, 123]
# ['구결경', 190, 49]
# ['소은준', 156, 67]
# ['최서하', 176, 99]
# ['감혜빈', 195, 54]
# ['배기빈', 198, 129]
# ['송흥경', 151, 54]
# ['최빈송', 162, 64]
# ['전보진', 175, 72]
# ['성영준', 151, 108]
# ['유성희', 166, 81]
# ['신동우', 191, 129]
# ['곽기우', 189, 77]
# ['위희태', 162, 112]
# ['백비준', 161, 58]
# ['표준희', 155, 119]
# ['주명교', 188, 45]
# ['배보교', 183, 40]
# ['김인용', 180, 130]
# ['임자경', 180, 60]
# ['곽종옥', 192, 113]
# ['홍보표', 195, 113]
# ['김수권', 197, 54]
# ['우영비', 175, 125]
# ['최희결', 169, 66]
# ['우명종', 171, 114]
# ['신성자', 155, 57]
# ['강권희', 193, 117]
# ['우민남', 152, 101]
# ['곽옥태', 163, 83]
# ['편정비', 150, 76]
# ['주기보', 197, 93]
# ['심현성', 164, 96]
# ['독고인비', 196, 125]
# ['김우성', 175, 78]
# ['소영배', 171, 77]
# ['유빈훈', 170, 115]
# ['박희배', 175, 97]
# ['홍영혜', 158, 64]
# ['제갈빈철', 199, 51]
# ['고하권', 190, 62]
# ['신보경', 192, 66]
# ['제갈인성', 168, 127]
# ['고순균', 191, 62]
# ['위빈철', 161, 63]
# ['주배표', 182, 100]
# ['편표준', 178, 43]
# ['정민철', 153, 42]
# ['선우재기', 197, 74]
# ['백아경', 157, 47]
# ['신현권', 177, 44]
# ['나동지', 200, 41]
# ['독고윤재', 183, 65]
# ['소결기', 163, 48]
# ['주검현', 158, 88]
# ['주종명', 160, 119]
# ['소빈동', 185, 115]
# ['독고배희', 151, 95]
# ['장송동', 196, 86]
# ['소검동', 199, 46]
# ['장아배', 157, 47]
# ['전자영', 159, 78]
# ['오웅하', 179, 105]
# ['위성종', 165, 51]
# ['표옥남', 162, 42]
# ['유비지', 194, 101]
# ['편석진', 191, 66]
# ['허비정', 173, 95]
# ['감서도', 177, 60]
# ['허훈다', 183, 97]
# ['우기종', 163, 127]
# ['표송혜', 188, 55]
# ['표윤수', 175, 101]
# ['박인웅', 163, 103]
# ['독고은교', 153, 93]
# ['고지훈', 181, 46]
# ['허수성', 151, 130]
# ['유호진', 191, 80]
# ['이호종', 197, 97]
# ['고석정', 153, 67]
# ['한흥용', 199, 57]
# ['곽정지', 171, 55]
# ['성배비', 156, 52]
# ['전석균', 193, 44]
# ['구다아', 190, 73]
# ['신송경', 192, 60]
# ['구자태', 183, 106]
# ['독고비우', 164, 111]
# ['나수도', 172, 71]
# ['제갈도우', 171, 95]
# ['홍다표', 150, 76]
# ['김현검', 190, 106]
# ['선우자민', 168, 120]
# ['정희종', 177, 101]
# ['독고종빈', 184, 91]
# ['전정자', 157, 45]
# ['강흥아', 189, 57]
# ['유비빈', 170, 74]
# ['고호성', 152, 63]
# ['허검정', 170, 60]
# ['백배석', 153, 129]
# ['구결흥', 175, 124]
# ['제갈성흥', 165, 82]
# ['성종명', 163, 87]
# ['전희현', 188, 58]
# ['송표현', 184, 103]
# ['김흥태', 189, 41]
# ['박수웅', 174, 84]
# ['송권보', 195, 53]
# ['송종종', 157, 94]
# ['김비배', 158, 52]
# ['정다호', 167, 85]
# ['이명서', 187, 64]
# ['조석하', 165, 49]
# ['곽표수', 197, 110]
# ['표정민', 179, 102]
# ['감권옥', 172, 117]
# ['백윤재', 198, 69]
# ['제갈명용', 156, 53]
# ['구현용', 152, 98]
# ['장결흥', 199, 55]
# ['구민윤', 175, 48]
# ['독고남도', 155, 128]
# ['장기진', 157, 107]
# ['나균아', 166, 125]
# ['구아수', 192, 53]
# ['표태옥', 183, 84]
# ['허자훈', 189, 88]
# ['심준은', 188, 119]
# ['최배흥', 163, 73]
# ['오균혜', 170, 51]
# ['백지검', 166, 128]
# ['구배다', 174, 93]
# ['조현재', 175, 111]
# ['송훈재', 173, 94]
# ['곽표윤', 167, 107]
# ['곽현진', 171, 58]
# ['오성빈', 158, 80]
# ['정혜호', 182, 42]
# ['강희옥', 196, 61]
# ['송혜경', 175, 41]
# ['선우정현', 198, 87]
# ['성자결', 193, 64]
# ['우성다', 191, 93]
# ['소수동', 191, 112]
# ['허윤지', 159, 81]
# ['허민하', 163, 103]
# ['제갈종성', 164, 99]
# ['유권호', 172, 57]
# ['주기민', 196, 109]
# ['이검윤', 173, 45]
# ['이검권', 163, 90]
# ['나인교', 166, 68]
# ['고철영', 197, 129]
# ['나균송', 154, 121]
# ['정희순', 190, 108]
# ['신인웅', 194, 107]
# ['오보명', 173, 75]
# ['주영현', 191, 53]
# ['구자성', 198, 56]
# ['곽배호', 167, 53]
# ['최표란', 160, 118]
# ['독고배다', 171, 64]
# ['김송보', 191, 90]
# ['박비훈', 172, 65]
# ['나도란', 157, 87]
# ['선우혜호', 172, 121]
# ['신균윤', 169, 45]
# ['편철아', 166, 129]
# ['배동지', 154, 129]
# ['임균하', 158, 129]
# ['편종순', 166, 109]
# ['허태인', 155, 112]
# ['표송균', 164, 85]
