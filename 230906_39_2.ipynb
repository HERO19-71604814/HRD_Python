# %% [markdown]
# # ※모듈을 활용한 선그래프 그리기

# %%
import matplotlib.pyplot as plt
import math

sin_value = []
for i in range(360):
    x = math.sin(math.radians(i))
    sin_value.append(x)

plt.figure(figsize=(10,5))
plt.plot(sin_value)
plt.show()
